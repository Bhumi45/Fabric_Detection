# %% [markdown]
# ## Setup RAPIDS

# %%
# !nvidia-smi
# Out:
# Sat Sep 28 02:46:34 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0              46W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# This get the RAPIDS-Colab install files and test check your GPU.  Run this and the next cell only.
# Please read the output of this cell.  If your Colab Instance is not RAPIDS compatible, it will warn you and give you remediation steps.
# !git clone https://github.com/rapidsai/rapidsai-csp-utils.git
# !python rapidsai-csp-utils/colab/env-check.py
# Out:
# Cloning into 'rapidsai-csp-utils'...
# remote: Enumerating objects: 511, done.
# remote: Counting objects: 100% (242/242), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 511 (delta 159), reused 124 (delta 91), pack-reused 269 (from 1)
# Receiving objects: 100% (511/511), 163.95 KiB | 777.00 KiB/s, done.
# Resolving deltas: 100% (261/261), done.
# Collecting pynvml
#   Downloading pynvml-11.5.3-py3-none-any.whl.metadata (8.8 kB)
# Downloading pynvml-11.5.3-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: pynvml
# Successfully installed pynvml-11.5.3
# ***********************************************************************
# Woo! Your instance has the right kind of GPU, a NVIDIA A100-SXM4-40GB!
# We will now install RAPIDS via pip!  Please stand by, should be quick...
# ***********************************************************************

# %%
# This will update the Colab environment and restart the kernel.  Don't run the next cell until you see the session crash.
# !bash rapidsai-csp-utils/colab/update_gcc.sh
import os
os._exit(00)
# Out:
# Updating your Colab environment.  This will restart your kernel.  Don't Panic!
# Found existing installation: cupy-cuda12x 12.2.0
# Uninstalling cupy-cuda12x-12.2.0:
#   Successfully uninstalled cupy-cuda12x-12.2.0
# restarting Colab...

# %%
# This will install CondaColab.  This will restart your kernel one last time.  Run this cell by itself and only run the next cell once you see the session crash.
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:07
# 🔁 Restarting kernel...

# %%
# you can now run the rest of the cells as normal
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# Installing RAPIDS is now 'python rapidsai-csp-utils/colab/install_rapids.py <release> <packages>'
# The <release> options are 'stable' and 'nightly'.  Leaving it blank or adding any other words will default to stable.
# !python rapidsai-csp-utils/colab/install_rapids.py stable
import os
os.environ['NUMBAPRO_NVVM'] = '/usr/local/cuda/nvvm/lib64/libnvvm.so'
os.environ['NUMBAPRO_LIBDEVICE'] = '/usr/local/cuda/nvvm/libdevice/'
os.environ['CONDA_PREFIX'] = '/usr/local'
# Out:
# Collecting pynvml
#   Using cached pynvml-11.5.3-py3-none-any.whl.metadata (8.8 kB)
# Using cached pynvml-11.5.3-py3-none-any.whl (53 kB)
# Installing collected packages: pynvml
# Successfully installed pynvml-11.5.3
# Found existing installation: cffi 1.16.0
# Uninstalling cffi-1.16.0:
#   Successfully uninstalled cffi-1.16.0
# WARNING: Skipping cryptography as it is not installed.
# Collecting cffi==1.15.0
#   Downloading cffi-1.15.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/site-packages (from cffi==1.15.0) (2.21)
# Downloading cffi-1.15.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (446 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.3/446.3 kB 12.1 MB/s eta 0:00:00
# Installing collected packages: cffi
# Successfully installed cffi-1.15.0
# Installing RAPIDS Stable 23.12
# Starting the RAPIDS install on Colab.  This will take about 15 minutes.
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - mamba
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     archspec-0.2.3             |     pyhd8ed1ab_0          48 KB  conda-forge
#     ca-certificates-2024.8.30  |       hbcca054_0         155 KB  conda-forge
#     certifi-2024.8.30          |     pyhd8ed1ab_0         160 KB  conda-forge
#     conda-24.7.1               |  py310hff52083_0         940 KB  conda-forge
#     fmt-10.2.1                 |       h00ab1b0_0         189 KB  conda-forge
#     frozendict-2.4.4           |  py310ha75aee5_1          48 KB  conda-forge
#     libcurl-8.8.0              |       hca28451_0         396 KB  conda-forge
#     libgcc-14.1.0              |       h77fa898_1         827 KB  conda-forge
#     libgcc-ng-14.1.0           |       h69a702a_1          51 KB  conda-forge
#     libgomp-14.1.0             |       h77fa898_1         449 KB  conda-forge
#     libmamba-1.5.8             |       had39da4_0         1.6 MB  conda-forge
#     libmambapy-1.5.8           |  py310h39ff949_0         302 KB  conda-forge
#     mamba-1.5.8                |  py310h51d5547_0          51 KB  conda-forge
#     openssl-3.3.2              |       hb9d3cd8_0         2.8 MB  conda-forge
#     zstandard-0.23.0           |  py310ha39cb0e_1         399 KB  conda-forge
#     zstd-1.5.6                 |       ha6fb4c9_0         542 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         8.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   frozendict         conda-forge/linux-64::frozendict-2.4.4-py310ha75aee5_1
#   libgcc             conda-forge/linux-64::libgcc-14.1.0-h77fa898_1
#
# The following packages will be UPDATED:
#
#   archspec                               0.2.2-pyhd8ed1ab_0 --> 0.2.3-pyhd8ed1ab_0
#   ca-certificates                     2023.11.17-hbcca054_0 --> 2024.8.30-hbcca054_0
#   certifi                           2023.11.17-pyhd8ed1ab_0 --> 2024.8.30-pyhd8ed1ab_0
#   conda                             23.11.0-py310hff52083_1 --> 24.7.1-py310hff52083_0
#   fmt                                     10.1.1-h00ab1b0_1 --> 10.2.1-h00ab1b0_0
#   libcurl                                  8.5.0-hca28451_0 --> 8.8.0-hca28451_0
#   libgcc-ng                               13.2.0-h807b86a_3 --> 14.1.0-h69a702a_1
#   libgomp                                 13.2.0-h807b86a_3 --> 14.1.0-h77fa898_1
#   libmamba                                 1.5.5-had39da4_0 --> 1.5.8-had39da4_0
#   libmambapy                          1.5.5-py310h39ff949_0 --> 1.5.8-py310h39ff949_0
#   mamba                               1.5.5-py310h51d5547_0 --> 1.5.8-py310h51d5547_0
#   openssl                                  3.2.0-hd590300_1 --> 3.3.2-hb9d3cd8_0
#   zstandard                          0.22.0-py310h1275a96_0 --> 0.23.0-py310ha39cb0e_1
#   zstd                                     1.5.5-hfc55251_0 --> 1.5.6-ha6fb4c9_0
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# warning  libmamba Could not parse mod/etag header
# warning  libmamba Could not parse mod/etag header
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - python=3.10
#    - cuda-version=12.0
#    - rapids=23.12
#    - llvmlite
#    - gcsfs
#    - openssl
#    - dask-sql
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                                 Version  Build                              Channel           Size
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + libstdcxx                              14.1.0  hc0a3c3a_1                         conda-forge        4MB
#   + psutil                                  6.0.0  py310ha75aee5_1                    conda-forge      371kB
#   + tornado                                 6.4.1  py310ha75aee5_1                    conda-forge      651kB
#   + libutf8proc                             2.8.0  h166bdaf_0                         conda-forge      101kB
#   + libabseil                          20230802.1  cxx17_h59595ed_0                   conda-forge        1MB
#   + libbrotlicommon                         1.1.0  hd590300_1                         conda-forge       69kB
#   + libcrc32c                               1.1.2  h9c3ff4c_0                         conda-forge       20kB
#   + lz4                                     4.3.3  py310hb259640_1                    conda-forge       37kB
#   + libpng                                 1.6.43  h2797004_0                         conda-forge      288kB
#   + websockets                               10.4  py310h5764c6d_1                    conda-forge      129kB
#   + libgfortran5                           14.1.0  hc5f4f2c_1                         conda-forge        1MB
#   + yaml                                    0.2.5  h7f98852_2                         conda-forge       89kB
#   + libjpeg-turbo                           3.0.0  hd590300_1                         conda-forge      619kB
#   + libdeflate                               1.19  hd590300_0                         conda-forge       67kB
#   + lerc                                    4.0.0  h27087fc_0                         conda-forge      282kB
#   + libwebp-base                            1.3.2  hd590300_1                         conda-forge      435kB
#   + snappy                                 1.1.10  hdb0a2a9_1                         conda-forge       40kB
#   + libllvm14                              14.0.6  hcd5def8_4                         conda-forge       31MB
#   + pthread-stubs                             0.4  hb9d3cd8_1002                      conda-forge        8kB
#   + xorg-libxau                            1.0.11  hb9d3cd8_1                         conda-forge       15kB
#   + xorg-libxdmcp                           1.1.3  hb9d3cd8_1                         conda-forge       20kB
#   + giflib                                  5.2.2  hd590300_0                         conda-forge       77kB
#   + libllvm15                              15.0.7  hb3ce162_4                         conda-forge       33MB
#   + aws-c-common                           0.9.12  hd590300_0                         conda-forge      225kB
#   + s2n                                     1.4.1  h06160fa_0                         conda-forge      331kB
#   + tzlocal                                   5.2  py310hff52083_1                    conda-forge       35kB
#   + frozenlist                              1.4.1  py310ha75aee5_1                    conda-forge       60kB
#   + zlib                                   1.2.13  hd590300_5                         conda-forge       93kB
#   + dlpack                                    0.5  h9c3ff4c_0                         conda-forge       13kB
#   + nvtx                                   0.2.10  py310h2372a71_0                    conda-forge      106kB
#   + sqlite                                 3.44.2  h2c6b66d_0                         conda-forge      836kB
#   + gtest                                  1.15.2  h434a139_0                         conda-forge      408kB
#   + jbig                                      2.1  h7f98852_2003                      conda-forge       44kB
#   + xorg-libice                             1.1.1  hd590300_0                         conda-forge       58kB
#   + libuv                                  1.48.0  hd590300_0                         conda-forge      900kB
#   + geos                                   3.12.0  h59595ed_0                         conda-forge        2MB
#   + cryptography                           43.0.1  py310h6c63255_0                    conda-forge        1MB
#   + markupsafe                              2.1.5  py310ha75aee5_1                    conda-forge       24kB
#   + pcre2                                   10.40  hc3806b6_0                         conda-forge        2MB
#   + libspatialindex                         2.0.0  he02047a_0                         conda-forge      391kB
#   + xorg-renderproto                       0.11.1  hb9d3cd8_1003                      conda-forge       12kB
#   + xorg-kbproto                            1.0.7  hb9d3cd8_1003                      conda-forge       30kB
#   + xorg-xextproto                          7.3.0  hb9d3cd8_1004                      conda-forge       31kB
#   + xorg-xproto                            7.0.31  hb9d3cd8_1008                      conda-forge       73kB
#   + libnl                                  3.10.0  h4bc722e_0                         conda-forge      734kB
#   + qhull                                  2020.2  h434a139_5                         conda-forge      553kB
#   + libevent                               2.1.12  hf998b51_1                         conda-forge      427kB
#   + gettext-tools                          0.22.5  he02047a_3                         conda-forge        3MB
#   + libasprintf                            0.22.5  he8f35ee_3                         conda-forge       43kB
#   + libgettextpo                           0.22.5  he02047a_3                         conda-forge      171kB
#   + unicodedata2                           15.1.0  py310h2372a71_0                    conda-forge      374kB
#   + libexpat                                2.6.3  h5888daf_0                         conda-forge       74kB
#   + nspr                                     4.35  h27087fc_0                         conda-forge      227kB
#   + libaec                                  1.1.3  h59595ed_0                         conda-forge       35kB
#   + minizip                                 4.0.6  h9d307f2_0                         conda-forge       91kB
#   + fastrlock                               0.8.2  py310hc6cd4ac_2                    conda-forge       38kB
#   + pixman                                 0.43.2  h59595ed_0                         conda-forge      387kB
#   + charls                                  2.4.2  h59595ed_0                         conda-forge      150kB
#   + rpds-py                                0.20.0  py310h505e2c1_1                    conda-forge      332kB
#   + argon2-cffi-bindings                   21.2.0  py310ha75aee5_5                    conda-forge       34kB
#   + xerces-c                                3.2.5  hac6953d_0                         conda-forge        2MB
#   + json-c                                   0.17  h1220068_1                         conda-forge       84kB
#   + libpq                                    16.1  h33b98f1_7                         conda-forge        2MB
#   + jxrlib                                    1.1  hd590300_3                         conda-forge      239kB
#   + zlib-ng                                 2.0.7  h0b41bf4_0                         conda-forge       95kB
#   + aom                                     3.9.1  hac33072_0                         conda-forge        3MB
#   + dav1d                                   1.2.1  hd590300_0                         conda-forge      760kB
#   + svt-av1                                 2.2.1  h5888daf_0                         conda-forge        2MB
#   + libhwy                                  1.1.0  h00ab1b0_0                         conda-forge        1MB
#   + libzip                                 1.10.1  h2629f0a_3                         conda-forge      107kB
#   + libboost-headers                       1.86.0  ha770c72_2                         conda-forge       14MB
#   + uriparser                               0.9.8  hac33072_0                         conda-forge       48kB
#   + rav1e                                   0.6.6  he8a937b_2                         conda-forge       15MB
#   + libsodium                              1.0.18  h36c2ea0_1                         conda-forge      375kB
#   + libzopfli                               1.0.3  h9c3ff4c_0                         conda-forge      168kB
#   + libntlm                                   1.4  h7f98852_1002                      conda-forge       33kB
#   + tzcode                                  2024b  hb9d3cd8_0                         conda-forge       69kB
#   + spdlog                                 1.11.0  h9b3ece8_1                         conda-forge      221kB
#   + zfp                                     1.0.1  h5888daf_2                         conda-forge      279kB
#   + kiwisolver                              1.4.7  py310h3788b33_0                    conda-forge       72kB
#   + gflags                                  2.2.2  h5888daf_1005                      conda-forge      120kB
#   + msgpack-python                          1.1.0  py310h3788b33_0                    conda-forge       98kB
#   + libre2-11                          2023.09.01  h7a70373_1                         conda-forge      233kB
#   + libprotobuf                            4.24.4  hf27288f_0                         conda-forge        3MB
#   + libbrotlienc                            1.1.0  hd590300_1                         conda-forge      283kB
#   + libbrotlidec                            1.1.0  hd590300_1                         conda-forge       33kB
#   + google-crc32c                           1.1.2  py310hd027165_6                    conda-forge       24kB
#   + freetype                               2.12.1  h267a509_2                         conda-forge      635kB
#   + libgfortran                            14.1.0  h69a702a_1                         conda-forge       52kB
#   + pyyaml                                  6.0.2  py310ha75aee5_1                    conda-forge      183kB
#   + hdf4                                   4.2.15  h2a13503_7                         conda-forge      757kB
#   + libtiff                                 4.6.0  ha9c0a0a_2                         conda-forge      283kB
#   + blosc                                  1.21.5  h0f2a231_0                         conda-forge       49kB
#   + llvmlite                               0.40.1  py310h1b8f574_0                    conda-forge        3MB
#   + libxcb                                   1.15  h0b41bf4_0                         conda-forge      384kB
#   + aws-c-compression                      0.2.17  h572eabf_8                         conda-forge       19kB
#   + aws-c-sdkutils                         0.1.13  h572eabf_1                         conda-forge       53kB
#   + aws-c-cal                               0.6.9  h14ec70c_3                         conda-forge       55kB
#   + aws-checksums                          0.1.17  h572eabf_7                         conda-forge       50kB
#   + gmock                                  1.15.2  ha770c72_0                         conda-forge        7kB
#   + xorg-libsm                              1.2.4  h7391055_0                         conda-forge       27kB
#   + nodejs                                20.12.2  hb753e55_0                         conda-forge       17MB
#   + librttopo                               1.1.0  hb58d41b_14                        conda-forge      233kB
#   + rtree                                   1.3.0  py310h8dc1cec_2                    conda-forge       58kB
#   + rdma-core                                53.0  he02047a_0                         conda-forge        5MB
#   + libthrift                              0.19.0  hb90f79a_1                         conda-forge      409kB
#   + libasprintf-devel                      0.22.5  he8f35ee_3                         conda-forge       34kB
#   + libgettextpo-devel                     0.22.5  he02047a_3                         conda-forge       37kB
#   + expat                                   2.6.3  h5888daf_0                         conda-forge      138kB
#   + nss                                      3.97  h1d7d5a4_0                         conda-forge        2MB
#   + freexl                                  2.0.0  h743c826_0                         conda-forge       60kB
#   + c-blosc2                               2.14.3  hb4ffafa_0                         conda-forge      337kB
#   + libkml                                  1.3.0  h01aab08_1018                      conda-forge      514kB
#   + libavif16                               1.1.1  h104a339_1                         conda-forge      116kB
#   + zeromq                                  4.3.5  h75354e8_4                         conda-forge      353kB
#   + cyrus-sasl                             2.1.27  h54b06d7_7                         conda-forge      220kB
#   + postgresql                               16.1  h7387d8b_7                         conda-forge        5MB
#   + glog                                    0.6.0  h6f12383_0                         conda-forge      114kB
#   + re2                                2023.09.01  h7f4b329_1                         conda-forge       27kB
#   + protobuf                               4.24.4  py310h620c231_0                    conda-forge      329kB
#   + orc                                     1.9.2  h4b38347_0                         conda-forge        1MB
#   + libjxl                                 0.10.3  h66b40c8_0                         conda-forge        2MB
#   + brotli-bin                              1.1.0  hd590300_1                         conda-forge       19kB
#   + libgfortran-ng                         14.1.0  h69a702a_1                         conda-forge       52kB
#   + proj                                    9.3.0  h1d62c97_2                         conda-forge        3MB
#   + libwebp                                 1.3.2  h658648e_1                         conda-forge       85kB
#   + openjpeg                                2.5.2  h488ebb8_0                         conda-forge      342kB
#   + lcms2                                    2.16  hb7c19ff_0                         conda-forge      245kB
#   + xorg-libx11                             1.8.9  h8ee46fc_0                         conda-forge      828kB
#   + aws-c-io                               0.14.0  hf8f278a_1                         conda-forge      157kB
#   + gettext                                0.22.5  he02047a_3                         conda-forge      479kB
#   + fontconfig                             2.14.2  h14ed4e7_0                         conda-forge      272kB
#   + pyzmq                                  26.2.0  py310h71f11fc_1                    conda-forge      338kB
#   + librdkafka                              1.9.2  ha5a0de0_2                         conda-forge       14MB
#   + libgrpc                                1.59.3  hd6c4280_0                         conda-forge        7MB
#   + brotli                                  1.1.0  hd590300_1                         conda-forge       19kB
#   + hdf5                                   1.14.3  nompi_hdf9ad27_105                 conda-forge        4MB
#   + cfitsio                                 4.2.0  hd9d235c_0                         conda-forge      848kB
#   + libopenblas                            0.3.27  pthreads_hac2b453_1                conda-forge        6MB
#   + geotiff                                 1.7.1  hf074850_14                        conda-forge      133kB
#   + libspatialite                           5.0.1  h090f1da_29                        conda-forge        3MB
#   + pyproj                                  3.6.1  py310h32c33b7_4                    conda-forge      527kB
#   + pillow                                 10.3.0  py310hf73ecf8_0                    conda-forge       42MB
#   + xorg-libxext                            1.3.4  h0b41bf4_2                         conda-forge       50kB
#   + xorg-libxrender                        0.9.11  hd590300_0                         conda-forge       38kB
#   + aws-c-http                              0.8.0  h9129f04_2                         conda-forge      195kB
#   + aws-c-event-stream                      0.4.1  h97bb272_2                         conda-forge       54kB
#   + libglib                                2.78.1  hebfc3b9_0                         conda-forge        3MB
#   + python-confluent-kafka                  1.9.2  py310h5764c6d_2                    conda-forge      149kB
#   + grpcio                                 1.59.3  py310h1b8f574_0                    conda-forge      991kB
#   + libgoogle-cloud                        2.12.0  h5206363_4                         conda-forge       43MB
#   + brunsli                                   0.1  h9c3ff4c_0                         conda-forge      205kB
#   + libnetcdf                               4.9.2  nompi_h9612171_113                 conda-forge      849kB
#   + kealib                                  1.5.3  hf8d3e68_2                         conda-forge      180kB
#   + libblas                                 3.9.0  24_linux64_openblas                conda-forge       15kB
#   + aws-c-mqtt                             0.10.1  h2b97f5f_0                         conda-forge      164kB
#   + aws-c-auth                             0.7.11  h0b4cabd_1                         conda-forge      103kB
#   + gdk-pixbuf                            2.42.10  h829c605_4                         conda-forge      572kB
#   + tiledb                                 2.16.3  h8c794c1_3                         conda-forge        6MB
#   + libcblas                                3.9.0  24_linux64_openblas                conda-forge       15kB
#   + liblapack                               3.9.0  24_linux64_openblas                conda-forge       15kB
#   + aws-c-s3                                0.4.9  hca09fc5_0                         conda-forge      106kB
#   + numpy                                  1.24.4  py310ha4c1d20_0                    conda-forge        7MB
#   + aws-crt-cpp                            0.26.0  h04327c0_8                         conda-forge      334kB
#   + imagecodecs                          2024.1.1  py310h0c5f7e8_2                    conda-forge        2MB
#   + pywavelets                              1.7.0  py310hf462985_1                    conda-forge        4MB
#   + shapely                                 2.0.2  py310h7dcad9a_0                    conda-forge      482kB
#   + cupy-core                              13.3.0  py310hc8bf42c_0                    conda-forge       41MB
#   + numba                                  0.57.1  py310h0f6aa51_0                    conda-forge        4MB
#   + scipy                                  1.14.1  py310ha3fb0e1_0                    conda-forge       17MB
#   + contourpy                               1.3.0  py310h3788b33_2                    conda-forge      261kB
#   + aws-sdk-cpp                          1.11.210  hba3e011_10                        conda-forge        4MB
#   + treelite                                3.9.1  py310h4a6579d_0                    conda-forge      765kB
#   + libarrow                               14.0.2  h84dd17c_3_cpu                     conda-forge       23MB
#   + libparquet                             14.0.2  h352af49_3_cpu                     conda-forge        1MB
#   + libarrow-gandiva                       14.0.2  hacb8726_3_cpu                     conda-forge      895kB
#   + libarrow-acero                         14.0.2  h59595ed_3_cpu                     conda-forge      577kB
#   + libarrow-dataset                       14.0.2  h59595ed_3_cpu                     conda-forge      582kB
#   + libarrow-substrait                     14.0.2  h61ff412_3_cpu                     conda-forge      509kB
#   + locket                                  1.0.0  pyhd8ed1ab_0                       conda-forge        8kB
#   + zict                                    3.0.0  pyhd8ed1ab_0                       conda-forge       36kB
#   + pynvml                                 11.4.1  pyhd8ed1ab_0                       conda-forge       41kB
#   + cuda-version                             12.0  hffde075_3                         conda-forge       21kB
#   + fsspec                               2024.9.0  pyhff2d567_0                       conda-forge      134kB
#   + decorator                               5.1.1  pyhd8ed1ab_0                       conda-forge       12kB
#   + click                                   8.1.7  unix_pyh707e725_0                  conda-forge       84kB
#   + cloudpickle                             3.0.0  pyhd8ed1ab_0                       conda-forge       25kB
#   + sortedcontainers                        2.4.0  pyhd8ed1ab_0                       conda-forge       26kB
#   + tblib                                   3.0.0  pyhd8ed1ab_0                       conda-forge       17kB
#   + toolz                                  0.12.1  pyhd8ed1ab_0                       conda-forge       52kB
#   + xyzservices                          2024.9.0  pyhd8ed1ab_0                       conda-forge       47kB
#   + six                                    1.16.0  pyh6c4a22f_0                       conda-forge       14kB
#   + appdirs                                 1.4.4  pyh9f0ad1d_0                       conda-forge       13kB
#   + pytz                                   2024.2  pyhd8ed1ab_0                       conda-forge      187kB
#   + tabulate                                0.9.0  pyhd8ed1ab_1                       conda-forge       36kB
#   + pygments                               2.18.0  pyhd8ed1ab_0                       conda-forge      879kB
#   + attrs                                  24.2.0  pyh71513ae_0                       conda-forge       56kB
#   + aiohappyeyeballs                        2.4.2  pyhd8ed1ab_0                       conda-forge       19kB
#   + networkx                                  3.3  pyhd8ed1ab_1                       conda-forge        1MB
#   + joblib                                  1.4.2  pyhd8ed1ab_0                       conda-forge      220kB
#   + font-ttf-dejavu-sans-mono                2.37  hab24e00_0                         conda-forge      397kB
#   + simpervisor                             1.0.0  pyhd8ed1ab_0                       conda-forge       13kB
#   + cachetools                              5.5.0  pyhd8ed1ab_0                       conda-forge       15kB
#   + typing_extensions                      4.12.2  pyha770c72_0                       conda-forge       40kB
#   + wcwidth                                0.2.13  pyhd8ed1ab_0                       conda-forge       33kB
#   + param                                   2.1.1  pyhff2d567_0                       conda-forge      103kB
#   + mdurl                                   0.1.2  pyhd8ed1ab_0                       conda-forge       15kB
#   + uc-micro-py                             1.0.3  pyhd8ed1ab_0                       conda-forge       11kB
#   + traitlets                              5.14.3  pyhd8ed1ab_0                       conda-forge      110kB
#   + zipp                                   3.20.2  pyhd8ed1ab_0                       conda-forge       21kB
#   + sniffio                                 1.3.1  pyhd8ed1ab_0                       conda-forge       15kB
#   + hpack                                   4.0.0  pyh9f0ad1d_0                       conda-forge       25kB
#   + colorcet                                3.1.0  pyhd8ed1ab_0                       conda-forge      174kB
#   + python-multipart                       0.0.10  pyhd8ed1ab_0                       conda-forge       27kB
#   + webencodings                            0.5.1  pyhd8ed1ab_2                       conda-forge       16kB
#   + exceptiongroup                          1.2.2  pyhd8ed1ab_0                       conda-forge       20kB
#   + pyasn1                                  0.6.1  pyhd8ed1ab_1                       conda-forge       62kB
#   + hyperframe                              6.0.1  pyhd8ed1ab_0                       conda-forge       15kB
#   + font-ttf-inconsolata                    3.000  h77eed37_0                         conda-forge       97kB
#   + font-ttf-source-code-pro                2.038  h77eed37_0                         conda-forge      701kB
#   + font-ttf-ubuntu                          0.83  h77eed37_2                         conda-forge        2MB
#   + cycler                                 0.12.1  pyhd8ed1ab_0                       conda-forge       13kB
#   + pyparsing                               3.1.4  pyhd8ed1ab_0                       conda-forge       90kB
#   + munkres                                 1.1.4  pyh9f0ad1d_0                       conda-forge       12kB
#   + munch                                   4.0.0  pyhd8ed1ab_0                       conda-forge       15kB
#   + shellingham                             1.5.4  pyhd8ed1ab_0                       conda-forge       15kB
#   + typing_utils                            0.1.0  pyhd8ed1ab_0                       conda-forge       14kB
#   + prometheus_client                      0.21.0  pyhd8ed1ab_0                       conda-forge       49kB
#   + rfc3986-validator                       0.1.1  pyh9f0ad1d_0                       conda-forge        8kB
#   + send2trash                              1.8.3  pyh0d859eb_0                       conda-forge       23kB
#   + websocket-client                        1.8.0  pyhd8ed1ab_0                       conda-forge       47kB
#   + python-json-logger                      2.0.7  pyhd8ed1ab_0                       conda-forge       13kB
#   + uri-template                            1.3.0  pyhd8ed1ab_0                       conda-forge       24kB
#   + webcolors                              24.8.0  pyhd8ed1ab_0                       conda-forge       18kB
#   + pkgutil-resolve-name                   1.3.10  pyhd8ed1ab_1                       conda-forge       11kB
#   + pyjwt                                   2.9.0  pyhd8ed1ab_1                       conda-forge       24kB
#   + blinker                                 1.8.2  pyhd8ed1ab_0                       conda-forge       15kB
#   + cached_property                         1.5.2  pyha770c72_1                       conda-forge       11kB
#   + threadpoolctl                           3.5.0  pyhc1e730c_0                       conda-forge       24kB
#   + poppler-data                           0.4.12  hd8ed1ab_0                         conda-forge        2MB
#   + ptyprocess                              0.7.0  pyhd3deb0d_0                       conda-forge       17kB
#   + python-fastjsonschema                  2.20.0  pyhd8ed1ab_0                       conda-forge      226kB
#   + defusedxml                              0.7.1  pyhd8ed1ab_0                       conda-forge       24kB
#   + entrypoints                               0.4  pyhd8ed1ab_0                       conda-forge        9kB
#   + pandocfilters                           1.5.0  pyhd8ed1ab_0                       conda-forge       12kB
#   + mistune                                 3.0.2  pyhd8ed1ab_0                       conda-forge       66kB
#   + soupsieve                                 2.5  pyhd8ed1ab_1                       conda-forge       37kB
#   + types-python-dateutil          2.9.0.20240906  pyhd8ed1ab_0                       conda-forge       22kB
#   + pyee                                    8.1.0  pyhd8ed1ab_0                       conda-forge       14kB
#   + aiosignal                               1.3.1  pyhd8ed1ab_0                       conda-forge       13kB
#   + pyopenssl                              24.2.1  pyhd8ed1ab_2                       conda-forge      128kB
#   + jinja2                                  3.1.4  pyhd8ed1ab_0                       conda-forge      112kB
#   + google-resumable-media                  2.7.2  pyhd8ed1ab_1                       conda-forge       46kB
#   + proto-plus                             1.23.0  pyhd8ed1ab_0                       conda-forge       42kB
#   + googleapis-common-protos               1.65.0  pyhd8ed1ab_0                       conda-forge      116kB
#   + imageio                                2.35.1  pyh12aca89_0                       conda-forge      293kB
#   + tifffile                            2024.9.20  pyhd8ed1ab_0                       conda-forge      181kB
#   + cuda-cccl_linux-64                    12.0.90  ha770c72_1                         conda-forge        1MB
#   + cuda-nvcc-dev_linux-64                12.0.76  ha770c72_1                         conda-forge        8MB
#   + cuda-cudart-static_linux-64          12.0.107  h59595ed_8                         conda-forge      655kB
#   + cuda-cudart_linux-64                 12.0.107  h59595ed_8                         conda-forge      183kB
#   + cligj                                   0.7.2  pyhd8ed1ab_1                       conda-forge       10kB
#   + click-plugins                           1.1.1  py_0                               conda-forge        9kB
#   + partd                                   1.4.2  pyhd8ed1ab_0                       conda-forge       21kB
#   + rfc3339-validator                       0.1.4  pyhd8ed1ab_0                       conda-forge        8kB
#   + multipledispatch                        0.6.0  pyhd8ed1ab_1                       conda-forge       17kB
#   + streamz                                 0.6.4  pyh6c4a22f_0                       conda-forge       65kB
#   + python-dateutil                         2.9.0  pyhd8ed1ab_0                       conda-forge      223kB
#   + pyu2f                                   0.1.5  pyhd8ed1ab_0                       conda-forge       32kB
#   + jupyterlab_pygments                     0.3.0  pyhd8ed1ab_1                       conda-forge       19kB
#   + referencing                            0.35.1  pyhd8ed1ab_0                       conda-forge       42kB
#   + typer-slim                             0.12.5  pyhd8ed1ab_0                       conda-forge       46kB
#   + h11                                    0.14.0  pyhd8ed1ab_0                       conda-forge       48kB
#   + typing-extensions                      4.12.2  hd8ed1ab_0                         conda-forge       10kB
#   + prompt-toolkit                         3.0.48  pyha770c72_0                       conda-forge      270kB
#   + pyct                                    0.5.0  pyhd8ed1ab_0                       conda-forge       20kB
#   + pyviz_comms                             3.0.3  pyhd8ed1ab_0                       conda-forge       48kB
#   + markdown-it-py                          3.0.0  pyhd8ed1ab_0                       conda-forge       64kB
#   + linkify-it-py                           2.0.3  pyhd8ed1ab_0                       conda-forge       24kB
#   + jupyter_core                            5.7.2  pyh31011fe_1                       conda-forge       58kB
#   + importlib_resources                     6.4.5  pyhd8ed1ab_0                       conda-forge       33kB
#   + importlib-metadata                      8.5.0  pyha770c72_0                       conda-forge       29kB
#   + dnspython                               2.6.1  pyhd8ed1ab_1                       conda-forge      169kB
#   + tinycss2                                1.3.0  pyhd8ed1ab_0                       conda-forge       25kB
#   + bleach                                  6.1.0  pyhd8ed1ab_0                       conda-forge      131kB
#   + anyio                                   4.6.0  pyhd8ed1ab_1                       conda-forge      108kB
#   + pyasn1-modules                          0.4.1  pyhd8ed1ab_0                       conda-forge       96kB
#   + rsa                                       4.9  pyhd8ed1ab_0                       conda-forge       30kB
#   + h2                                      4.1.0  pyhd8ed1ab_0                       conda-forge       47kB
#   + fonts-conda-forge                           1  0                                  conda-forge        4kB
#   + overrides                               7.7.0  pyhd8ed1ab_0                       conda-forge       30kB
#   + oauthlib                                3.2.2  pyhd8ed1ab_0                       conda-forge       92kB
#   + cached-property                         1.5.2  hd8ed1ab_1                         conda-forge        4kB
#   + terminado                              0.18.1  pyh0d859eb_0                       conda-forge       22kB
#   + beautifulsoup4                         4.12.3  pyha770c72_0                       conda-forge      118kB
#   + branca                                  0.7.2  pyhd8ed1ab_0                       conda-forge       29kB
#   + cuda-cudart-dev_linux-64             12.0.107  h59595ed_8                         conda-forge      326kB
#   + arrow                                   1.3.0  pyhd8ed1ab_0                       conda-forge      100kB
#   + argon2-cffi                            23.1.0  pyhd8ed1ab_0                       conda-forge       19kB
#   + annotated-types                         0.7.0  pyhd8ed1ab_0                       conda-forge       18kB
#   + async-timeout                           4.0.3  pyhd8ed1ab_0                       conda-forge       11kB
#   + mdit-py-plugins                         0.4.2  pyhd8ed1ab_0                       conda-forge       42kB
#   + rich                                   13.8.1  pyhd8ed1ab_0                       conda-forge      185kB
#   + jsonschema-specifications           2023.12.1  pyhd8ed1ab_0                       conda-forge       16kB
#   + jupyter_client                          8.6.3  pyhd8ed1ab_0                       conda-forge      106kB
#   + markdown                                  3.6  pyhd8ed1ab_0                       conda-forge       78kB
#   + lazy-loader                               0.4  pyhd8ed1ab_1                       conda-forge       16kB
#   + importlib_metadata                      8.5.0  hd8ed1ab_0                         conda-forge        9kB
#   + pyppeteer                               1.0.2  pyhd8ed1ab_0                       conda-forge       64kB
#   + email-validator                         2.2.0  pyhd8ed1ab_0                       conda-forge       44kB
#   + starlette                              0.38.6  pyhd8ed1ab_0                       conda-forge       57kB
#   + httpcore                                1.0.5  pyhd8ed1ab_0                       conda-forge       46kB
#   + fonts-conda-ecosystem                       1  0                                  conda-forge        4kB
#   + requests-oauthlib                       2.0.0  pyhd8ed1ab_0                       conda-forge       26kB
#   + fqdn                                    1.5.1  pyhd8ed1ab_0                       conda-forge       14kB
#   + jupyter_server_terminals                0.5.3  pyhd8ed1ab_0                       conda-forge       20kB
#   + folium                                 0.17.0  pyhd8ed1ab_0                       conda-forge       79kB
#   + isoduration                           20.11.0  pyhd8ed1ab_0                       conda-forge       17kB
#   + typer-slim-standard                    0.12.5  hd8ed1ab_0                         conda-forge       47kB
#   + jsonschema                             4.23.0  pyhd8ed1ab_0                       conda-forge       74kB
#   + lazy_loader                               0.4  pyhd8ed1ab_1                       conda-forge        7kB
#   + dask-core                           2023.11.0  pyhd8ed1ab_0                       conda-forge      863kB
#   + email_validator                         2.2.0  hd8ed1ab_0                         conda-forge        7kB
#   + httpx                                  0.27.2  pyhd8ed1ab_0                       conda-forge       65kB
#   + typer                                  0.12.5  pyhd8ed1ab_0                       conda-forge       53kB
#   + jsonschema-with-format-nongpl          4.23.0  hd8ed1ab_0                         conda-forge        7kB
#   + nbformat                               5.10.4  pyhd8ed1ab_0                       conda-forge      101kB
#   + jupyter_events                         0.10.0  pyhd8ed1ab_0                       conda-forge       21kB
#   + nbclient                               0.10.0  pyhd8ed1ab_0                       conda-forge       28kB
#   + nbconvert-core                         7.16.4  pyhd8ed1ab_1                       conda-forge      190kB
#   + jupyter_server                         2.14.2  pyhd8ed1ab_0                       conda-forge      324kB
#   + ucx-proc                                1.0.0  gpu                                rapidsai           9kB
#   + librmm                               23.12.00  cuda12_231206_g2db5cbb3_0          rapidsai           1MB
#   + cuda-nvcc-tools                       12.0.76  h59595ed_1                         conda-forge       31MB
#   + libnvjpeg                           12.0.0.28  h59595ed_1                         conda-forge        2MB
#   + nvcomp                                  3.0.4  h10b603f_1                         conda-forge        9MB
#   + libcufft                            11.0.0.21  hd3aeb46_2                         conda-forge       45MB
#   + libcufile                            1.5.0.59  hd3aeb46_1                         conda-forge      686kB
#   + cuda-nvrtc                            12.0.76  hd3aeb46_2                         conda-forge       18MB
#   + libnvjitlink                          12.0.76  hd3aeb46_2                         conda-forge       15MB
#   + nccl                                 2.23.4.1  h52f6c39_0                         conda-forge      114MB
#   + libcurand                           10.3.1.50  hd3aeb46_1                         conda-forge       42MB
#   + cytoolz                                0.12.3  py310h2372a71_0                    conda-forge      368kB
#   + fonttools                              4.54.1  py310ha75aee5_0                    conda-forge        2MB
#   + scikit-learn                            1.5.2  py310h27f47ee_1                    conda-forge        9MB
#   + cuda-cudart-static                   12.0.107  hd3aeb46_8                         conda-forge       23kB
#   + cuda-cudart                          12.0.107  hd3aeb46_8                         conda-forge       22kB
#   + pandas                                  1.5.3  py310h9b08913_1                    conda-forge       12MB
#   + uvicorn                                0.30.6  py310hff52083_0                    conda-forge      102kB
#   + pydantic-core                          2.23.4  py310h505e2c1_0                    conda-forge        2MB
#   + multidict                               6.1.0  py310ha75aee5_0                    conda-forge       58kB
#   + cairo                                  1.18.0  h3faef2a_0                         conda-forge      982kB
#   + scikit-image                           0.21.0  py310hc6cd4ac_0                    conda-forge       11MB
#   + libcufile-dev                        1.5.0.59  hd3aeb46_1                         conda-forge       33kB
#   + cuda-python                            12.6.0  py310h521d3fa_0                    conda-forge        6MB
#   + libcublas                          12.0.1.189  hd3aeb46_3                         conda-forge      234MB
#   + libcusparse                         12.0.0.76  hd3aeb46_2                         conda-forge       98MB
#   + libcurand-dev                       10.3.1.50  hd3aeb46_1                         conda-forge      256kB
#   + matplotlib-base                         3.9.2  py310h68603db_1                    conda-forge        7MB
#   + cuda-cudart-dev                      12.0.107  hd3aeb46_8                         conda-forge       23kB
#   + ucx                                    1.15.0  hda83522_8                         conda-forge        7MB
#   + yarl                                   1.13.0  py310ha75aee5_0                    conda-forge      145kB
#   + poppler                               23.10.0  h590f24d_0                         conda-forge        2MB
#   + openslide                               3.4.1  h58ba908_12                        conda-forge      112kB
#   + libcublas-dev                      12.0.1.189  hd3aeb46_3                         conda-forge       89kB
#   + libcusolver                         11.4.2.57  hd3aeb46_2                         conda-forge       59MB
#   + libcusparse-dev                     12.0.0.76  hd3aeb46_2                         conda-forge       51kB
#   + cuda-nvcc-impl                        12.0.76  h59595ed_1                         conda-forge        9MB
#   + cuda-profiler-api                     12.0.76  ha770c72_0                         conda-forge       23kB
#   + libarrow-flight                        14.0.2  h120cb0d_3_cpu                     conda-forge      501kB
#   + aiohttp                                3.10.6  py310ha75aee5_0                    conda-forge      724kB
#   + libgdal                                 3.6.4  hb454697_22                        conda-forge       10MB
#   + libcusolver-dev                     11.4.2.57  hd3aeb46_2                         conda-forge       63kB
#   + cupy                                   13.3.0  py310h1b77274_0                    conda-forge      355kB
#   + libarrow-flight-sql                    14.0.2  h61ff412_3_cpu                     conda-forge      196kB
#   + gdal                                    3.6.4  py310h5c4b078_22                   conda-forge        1MB
#   + pyarrow                                14.0.2  py310hf9e7431_3_cpu                conda-forge        4MB
#   + fiona                                   1.9.3  py310ha325b7b_0                    conda-forge      902kB
#   + libxgboost                              1.7.6  rapidsai_h52ede06_7                rapidsai         118MB
#   + libraft-headers-only                 23.12.00  cuda12_231206_g9e2d6277_0          rapidsai           2MB
#   + libkvikio                            23.12.00  cuda12_231206_gf90bfbe_0           rapidsai          37kB
#   + rmm                                  23.12.00  cuda12_py310_231206_g2db5cbb3_0    rapidsai         655kB
#   + ucx-py                                0.35.00  py310_231206_gb5f60ca_0            rapidsai         457kB
#   + libcucim                             23.12.01  cuda12_231211_ga3445df_0           rapidsai           5MB
#   + py-xgboost                              1.7.6  rapidsai_py310h4c2db5f_7           rapidsai         216kB
#   + libraft-headers                      23.12.00  cuda12_231206_g9e2d6277_0          rapidsai           6kB
#   + libcudf                              23.12.01  cuda12_231208_g2ce46216b5_0        rapidsai         297MB
#   + cuproj                               23.12.01  cuda12_py310_231207_g16727064_0    rapidsai         856kB
#   + cucim                                23.12.01  cuda12_py310_231211_ga3445df_0     rapidsai           4MB
#   + xgboost                                 1.7.6  rapidsai_py310h4c2db5f_7           rapidsai          16kB
#   + libraft                              23.12.00  cuda12_231206_g9e2d6277_0          rapidsai         665MB
#   + libcuspatial                         23.12.01  cuda12_231207_g16727064_0          rapidsai          28MB
#   + libcudf_kafka                        23.12.01  cuda12_231208_g2ce46216b5_0        rapidsai          38kB
#   + cudf                                 23.12.01  cuda12_py310_231208_g2ce46216b5_0  rapidsai           8MB
#   + rapids-xgboost                       23.12.00  cuda12_py310_231206_g1d8bed4_0     rapidsai           5kB
#   + pylibraft                            23.12.00  cuda12_py310_231206_g9e2d6277_0    rapidsai           2MB
#   + cudf_kafka                           23.12.01  cuda12_py310_231208_g2ce46216b5_0  rapidsai          81kB
#   + distributed                         2023.11.0  pyhd8ed1ab_0                       conda-forge      792kB
#   + xarray                               2024.3.0  pyhd8ed1ab_0                       conda-forge      765kB
#   + mapclassify                             2.8.1  pyhd8ed1ab_0                       conda-forge       58kB
#   + geopandas-base                         0.14.4  pyha770c72_0                       conda-forge        1MB
#   + bokeh                                   3.5.2  pyhd8ed1ab_0                       conda-forge        5MB
#   + pydantic                                2.9.2  pyhd8ed1ab_0                       conda-forge      301kB
#   + jupyter-server-proxy                    4.4.0  pyhd8ed1ab_0                       conda-forge       37kB
#   + google-auth                            2.35.0  pyhff2d567_0                       conda-forge      115kB
#   + pyarrow-hotfix                            0.6  pyhd8ed1ab_0                       conda-forge       14kB
#   + datashader                             0.16.3  pyhd8ed1ab_0                       conda-forge       17MB
#   + geopandas                              0.14.4  pyhd8ed1ab_0                       conda-forge        8kB
#   + panel                                   1.5.0  pyhd8ed1ab_0                       conda-forge       21MB
#   + fastapi                               0.115.0  pyhd8ed1ab_0                       conda-forge       73kB
#   + fastapi-cli                             0.0.5  pyhd8ed1ab_0                       conda-forge       14kB
#   + google-api-core                        2.20.0  pyhd8ed1ab_0                       conda-forge       86kB
#   + google-auth-oauthlib                    1.2.1  pyhd8ed1ab_0                       conda-forge       25kB
#   + dask                                2023.11.0  pyhd8ed1ab_0                       conda-forge        7kB
#   + holoviews                              1.19.1  pyhd8ed1ab_0                       conda-forge        4MB
#   + google-cloud-core                       2.4.1  pyhd8ed1ab_0                       conda-forge       28kB
#   + google-cloud-storage                   2.18.2  pyhff2d567_0                       conda-forge       91kB
#   + gcsfs                                2024.9.0  pyhd8ed1ab_0                       conda-forge       37kB
#   + libcumlprims                         23.12.00  cuda12_231206_gc120fe0_0           nvidia             5MB
#   + libcugraphops                        23.12.00  cuda12_231206_g42d08202_0          nvidia            40MB
#   + cuspatial                            23.12.01  cuda12_py310_231207_g16727064_0    rapidsai           1MB
#   + libcuml                              23.12.00  cuda12_231206_gad2bd2b65_0         rapidsai         265MB
#   + libcugraph                           23.12.00  cuda12_231206_g1309813f_0          rapidsai         638MB
#   + pylibcugraph                         23.12.00  cuda12_py310_231206_g1309813f_0    rapidsai         772kB
#   + libcugraph_etl                       23.12.00  cuda12_231206_g1309813f_0          rapidsai         612kB
#   + rapids-dask-dependency               23.12.01  0                                  rapidsai           8kB
#   + dask-sql                             2024.1.0  py310hac45122_0                    conda-forge       12MB
#   + dask-cudf                            23.12.01  cuda12_py310_231208_g2ce46216b5_0  rapidsai         136kB
#   + custreamz                            23.12.01  cuda12_py310_231208_g2ce46216b5_0  rapidsai          34kB
#   + dask-cuda                            23.12.00  py310_231206_ge1638ae_0            rapidsai         189kB
#   + cuxfilter                            23.12.00  cuda12_py310_231206_g63dabeb_0     rapidsai         112kB
#   + raft-dask                            23.12.00  cuda12_py310_231206_g9e2d6277_0    rapidsai         416kB
#   + cuml                                 23.12.00  cuda12_py310_231206_gad2bd2b65_0   rapidsai          10MB
#   + cugraph                              23.12.00  cuda12_py310_231206_g1309813f_0    rapidsai           2MB
#   + rapids                               23.12.00  cuda12_py310_231206_g1d8bed4_0     rapidsai           6kB
#
#   Downgrade:
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   - fmt                                    10.2.1  h00ab1b0_0                         conda-forge     Cached
#   + fmt                                     9.1.0  h924138e_0                         conda-forge      190kB
#   - libarchive                              3.7.2  h2aa1ff5_1                         conda-forge     Cached
#   + libarchive                              3.6.2  h039dbb9_1                         conda-forge      844kB
#   - ruamel.yaml                            0.18.5  py310h2372a71_0                    conda-forge     Cached
#   + ruamel.yaml                           0.17.40  py310h2372a71_0                    conda-forge      200kB
#   - yaml-cpp                                0.8.0  h59595ed_0                         conda-forge     Cached
#   + yaml-cpp                                0.7.0  h59595ed_3                         conda-forge      207kB
#   - libmamba                                1.5.8  had39da4_0                         conda-forge     Cached
#   + libmamba                                1.5.0  h658169a_0                         conda-forge        2MB
#   - libmambapy                              1.5.8  py310h39ff949_0                    conda-forge     Cached
#   + libmambapy                              1.5.0  py310h8aae740_0                    conda-forge      297kB
#   - urllib3                                 2.1.0  pyhd8ed1ab_0                       conda-forge     Cached
#   + urllib3                               1.26.19  pyhd8ed1ab_0                       conda-forge      115kB
#   - conda                                  24.7.1  py310hff52083_0                    conda-forge     Cached
#   + conda                                  23.7.4  py310hff52083_0                    conda-forge        1MB
#   - mamba                                   1.5.8  py310h51d5547_0                    conda-forge     Cached
#   + mamba                                   1.5.0  py310h51d5547_0                    conda-forge       51kB
#   - conda-libmamba-solver                 23.12.0  pyhd8ed1ab_0                       conda-forge     Cached
#   + conda-libmamba-solver                  23.7.0  pyhd8ed1ab_0                       conda-forge       42kB
#
#   Summary:
#
#   Install: 435 packages
#   Downgrade: 10 packages
#
#   Total download: 3GB
#
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
#
# Looking for: ['python=3.10', 'cuda-version=12.0', 'rapids=23.12', 'llvmlite', 'gcsfs', 'openssl', 'dask-sql']
#
#
# Pinned packages:
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
#
# Downloading and Extracting Packages: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
# done
# RAPIDS conda installation complete.  Updating Colab's libraries...
# Copying /usr/local/lib/libcudf.so to /usr/lib/libcudf.so
# Copying /usr/local/lib/libnccl.so to /usr/lib/libnccl.so
# Copying /usr/local/lib/libcuml.so to /usr/lib/libcuml.so
# Copying /usr/local/lib/libcugraph.so to /usr/lib/libcugraph.so
# Copying /usr/local/lib/libxgboost.so to /usr/lib/libxgboost.so
# Copying /usr/local/lib/libtreelite.so to /usr/lib/libtreelite.so
# Copying /usr/local/lib/libcuspatial.so to /usr/lib/libcuspatial.so
# Copying /usr/local/lib/libgeos.so to /usr/lib/libgeos.so
# Copying /usr/local/lib/libgeos_c.so to /usr/lib/libgeos_c.so

# %%
# !pip uninstall numba
# Out:
# Found existing installation: numba 0.57.1
# Uninstalling numba-0.57.1:
#   Would remove:
#     /usr/local/bin/numba
#     /usr/local/lib/python3.10/site-packages/numba-0.57.1.dist-info/*
#     /usr/local/lib/python3.10/site-packages/numba/*
# Proceed (Y/n)? Y
#   Successfully uninstalled numba-0.57.1

# %%
# !pip install numba
# Out:
# Collecting numba
#   Using cached numba-0.60.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba)
#   Using cached llvmlite-0.43.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy<2.1,>=1.22 in /usr/local/lib/python3.10/site-packages (from numba) (1.24.4)
# Using cached numba-0.60.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
# Using cached llvmlite-0.43.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.9 MB)
# Installing collected packages: llvmlite, numba
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.40.1
#     Uninstalling llvmlite-0.40.1:
#       Successfully uninstalled llvmlite-0.40.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.12.1 requires cubinlinker, which is not installed.
# cudf 23.12.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.12.1 requires ptxcompiler, which is not installed.
# cugraph 23.12.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cugraph 23.12.0 requires rapids-dask-dependency==23.12.*, which is not installed.
# cuml 23.12.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cuml 23.12.0 requires rapids-dask-dependency==23.12.*, which is not installed.
# cuxfilter 23.12.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cuda 23.12.0 requires rapids-dask-dependency==23.12.*, which is not installed.
# dask-cudf 23.12.1 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.12.1 requires rapids-dask-dependency==23.12.*, which is not installed.
# raft-dask 23.12.0 requires rapids-dask-dependency==23.12.*, which is not installed.
# cudf 23.12.1 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.6.0 which is incompatible.
# cudf 23.12.1 requires numba<0.58,>=0.57, but you have numba 0.60.0 which is incompatible.
# rmm 23.12.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.6.0 which is incompatible.
# Successfully installed llvmlite-0.43.0 numba-0.60.0

# %%
pip install dask-ml
# Out:
# Collecting dask-ml
#   Downloading dask_ml-2024.4.4-py3-none-any.whl.metadata (5.9 kB)
# Collecting dask-glm>=0.2.0 (from dask-ml)
#   Downloading dask_glm-0.3.2-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: dask>=2.4.0 in /usr/local/lib/python3.10/site-packages (from dask[array,dataframe]>=2.4.0->dask-ml) (2023.11.0)
# Requirement already satisfied: distributed>=2.4.0 in /usr/local/lib/python3.10/site-packages (from dask-ml) (2023.11.0)
# Requirement already satisfied: multipledispatch>=0.4.9 in /usr/local/lib/python3.10/site-packages (from dask-ml) (0.6.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/site-packages (from dask-ml) (0.60.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/site-packages (from dask-ml) (1.24.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/site-packages (from dask-ml) (23.2)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/site-packages (from dask-ml) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.10/site-packages (from dask-ml) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/site-packages (from dask-ml) (1.14.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.10/site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask-ml) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask-ml) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask-ml) (2024.9.0)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask-ml) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask-ml) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask-ml) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/site-packages (from dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask-ml) (8.5.0)
# Collecting sparse>=0.7.0 (from dask-glm>=0.2.0->dask-ml)
#   Downloading sparse-0.15.4-py2.py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.10/site-packages (from distributed>=2.4.0->dask-ml) (3.1.4)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/site-packages (from distributed>=2.4.0->dask-ml) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /usr/local/lib/python3.10/site-packages (from distributed>=2.4.0->dask-ml) (1.1.0)
# Requirement already satisfied: psutil>=5.7.2 in /usr/local/lib/python3.10/site-packages (from distributed>=2.4.0->dask-ml) (6.0.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.10/site-packages (from distributed>=2.4.0->dask-ml) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/site-packages (from distributed>=2.4.0->dask-ml) (3.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /usr/local/lib/python3.10/site-packages (from distributed>=2.4.0->dask-ml) (6.4.1)
# Requirement already satisfied: urllib3>=1.24.3 in /usr/local/lib/python3.10/site-packages (from distributed>=2.4.0->dask-ml) (1.26.19)
# Requirement already satisfied: zict>=3.0.0 in /usr/local/lib/python3.10/site-packages (from distributed>=2.4.0->dask-ml) (3.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/site-packages (from multipledispatch>=0.4.9->dask-ml) (1.16.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/site-packages (from numba>=0.51.0->dask-ml) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/site-packages (from pandas>=0.24.2->dask-ml) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas>=0.24.2->dask-ml) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/site-packages (from scikit-learn>=1.2.0->dask-ml) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/site-packages (from scikit-learn>=1.2.0->dask-ml) (3.5.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/site-packages (from importlib-metadata>=4.13.0->dask>=2.4.0->dask[array,dataframe]>=2.4.0->dask-ml) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/site-packages (from jinja2>=2.10.3->distributed>=2.4.0->dask-ml) (2.1.5)
# Downloading dask_ml-2024.4.4-py3-none-any.whl (149 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.8/149.8 kB 5.6 MB/s eta 0:00:00
# Downloading dask_glm-0.3.2-py2.py3-none-any.whl (13 kB)
# Downloading sparse-0.15.4-py2.py3-none-any.whl (237 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.3/237.3 kB 16.9 MB/s eta 0:00:00
# Installing collected packages: sparse, dask-glm, dask-ml
# Successfully installed dask-glm-0.3.2 dask-ml-2024.4.4 sparse-0.15.4

# %%
import os
import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
from joblib import dump

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GroupShuffleSplit
from sklearn.model_selection import GroupKFold
#from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import classification_report, confusion_matrix
#from sklearn.preprocessing import LabelEncoder

# %%
# CUDA libraries
import cupy as cp
import cudf
from cuml.preprocessing import StandardScaler
from cuml.preprocessing.LabelEncoder import LabelEncoder
from cuml import PCA
import dask_ml.model_selection as dcv
from cuml.ensemble import RandomForestClassifier
from cuml.svm import SVC

# %% [markdown]
# **Loading the saved data and labels**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load from the .npz files


# Paths to the .npz files
output_dir = '/content/drive/My Drive/Fabric Detection Project/Extracted Features'
data_path = os.path.join(output_dir, 'data.npz')
labels_path = os.path.join(output_dir, 'labels.npz')
groups_path = os.path.join(output_dir, 'groups.npz')


# Loading the .npz files
data = np.load(data_path)
labels = np.load(labels_path)
groups = np.load(groups_path)

#  Access the arrays stored inside the .npz files
X = data['data']
y = labels['labels']
groups = groups['groups']
# Known values
#total_images = 17780  # Total original images + augmentations
#feature_size = 49162   # Number of features per image

# Load the memory-mapped arrays for reading
#X = np.memmap(data_file, dtype='float32', mode='r', shape=(total_images, feature_size))
#y = np.memmap(labels_file, dtype='object', mode='r', shape=(total_images,))
#groups = np.memmap(groups_file, dtype='int32', mode='r', shape=(total_images,))

# %%
# Checking the data type of X,y and groups
print(f"Type of X {type(X)}")
print(f"Type of y {type(y)}")
print(f"Type of groups {type(groups)}")
# Out:
# Type of X <class 'numpy.ndarray'>
# Type of y <class 'numpy.ndarray'>
# Type of groups <class 'numpy.ndarray'>

# %%
# Checking the shape of the dataset and the labels
print(f"Dataset shape: {X.shape}")
print(f"Labels shape: {y.shape}")
print(f"Groups shape: {groups.shape}")
# Out:
# Dataset shape: (17875, 49162)
# Labels shape: (17875,)
# Groups shape: (17875,)

# %%
print(y)

# %% [markdown]
# **Encoding the target variable**

# %%
# Example array with categories
categories = ['linen', 'cotton', 'wool', 'denim', 'corduroy']

# Create a dictionary for manual mapping
category_mapping = { 'corduroy': 1, 'cotton': 2, 'denim': 3, 'linin': 4, 'wool': 5}

# Convert to pandas Series (optional if already in pandas)
y_series = pd.Series(y)

# Map categories to numbers
mapped_categories = y_series.map(category_mapping)
y = np.array(mapped_categories)


#print(y)
print(y.shape)
# Out:
# (17875,)

# %%
print(y_series.value_counts())
print(mapped_categories.value_counts())
# Out:
# cotton      3630
# linin       3585
# denim       3575
# corduroy    3550
# wool        3535
# dtype: int64
# 2    3630
# 4    3585
# 3    3575
# 1    3550
# 5    3535
# dtype: int64

# %%
# Since X,y and groups are numpy arrays , let's convert them to cupy arrays
X = cp.array(X)
y = cp.array(y)
groups= cp.array(groups)

# %%
# Checking the data type of X,y and groups
print(f"Type of X {type(X)}")
print(f"Type of y {type(y)}")
print(f"Type of groups {type(groups)}")
# Out:
# Type of X <class 'cupy.ndarray'>
# Type of y <class 'cupy.ndarray'>
# Type of groups <class 'cupy.ndarray'>

# %%
del y_series

# %%
del mapped_categories

# %% [markdown]
# - **Splitting the original dataset into train(80%) and test(20%) using GroupShuffleSplit to ensure that the same group of images are either in the train or the test dataset only.**

# %%
gss = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx, test_idx = next(gss.split(cp.asnumpy(X), cp.asnumpy(y), groups=cp.asnumpy(groups)))

X_train, X_test = X[train_idx], X[test_idx]
y_train, y_test = y[train_idx], y[test_idx]
groups_train = groups[train_idx]

# %% [markdown]
# ## Nested cross-validation setup

# %% [markdown]
# ###  Define Outer Loop: Model Evaluation

# %%
outer_cv = GroupKFold(n_splits=5)

# %% [markdown]
# **Split Training Data into Outer Training and Validation Folds**

# %%
# outer_train_idx: Indices for the training data in the current fold
# outer_val_idx: Indices for the testing data in the current fold

# The following loops runs 5 times as the no of splits in outer_cv has been defined as 5
count=1
for outer_train_idx, outer_val_idx in outer_cv.split(cp.asnumpy(X_train), cp.asnumpy(y_train), groups=cp.asnumpy(groups_train)):
    # Train data for the current fold
    X_outer_train = X_train[outer_train_idx] # Training features
    y_outer_train = y_train[outer_train_idx] # Training lables
    groups_outer_train = groups_train[outer_train_idx] # Training groups

    # Validation data for the current fold
    X_outer_val = X_train[outer_val_idx] # Validation features
    y_outer_val = y_train[outer_val_idx] # Validation labels

    svm_model, rf_model = start_inner_loop()

    if not os.path.exists("Models"):
        os.makedirs("Models")

    dump(svm_model, f'Models\\svm_{count}.joblib')
    dump(rf_model,f"Models\\rf_{count}.joblib")
    count+=1
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-29-4c3433bd32f9> in <cell line: 6>()
#      14     y_outer_val = y_train[outer_val_idx] # Validation labels
#      15
# ---> 16     svm_model, rf_model = start_inner_loop()
#      17
#      18     if not os.path.exists("Models"):
#
# <ipython-input-20-076bebe01b27> in start_inner_loop()
#       9
#      10     # Performing RandomSearchCV for SVM and RF
# ---> 11     random_search_svm = randomized_search_svm(pipeline_svm,param_grid_svm,inner_cv)
#      12     random_search_rf = randomized_search_rf(pipeline_rf,param_grid_rf,inner_cv)
#      13
#
# <ipython-input-23-538fabedecdb> in randomized_search_svm(pipeline_svm, param_grid_svm, inner_cv)
#      11     )
#      12
# ---> 13     random_search_svm.fit(X_outer_train, y_outer_train)
#      14
#      15     return random_search_svm
#
# /usr/local/lib/python3.10/site-packages/dask_ml/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#    1281             out = [result_map[k] for k in keys]
#    1282         else:
# -> 1283             out = scheduler(dsk, keys, num_workers=n_jobs)
#    1284
#    1285         if self.iid:
#
# /usr/local/lib/python3.10/site-packages/dask/threaded.py in get(dsk, keys, cache, num_workers, pool, **kwargs)
#      88             pool = MultiprocessingPoolExecutor(pool)
#      89
# ---> 90     results = get_async(
#      91         pool.submit,
#      92         pool._max_workers,
#
# /usr/local/lib/python3.10/site-packages/dask/local.py in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     510                             _execute_task(task, data)  # Re-execute locally
#     511                         else:
# --> 512                             raise_exception(exc, tb)
#     513                     res, worker_id = loads(res_info)
#     514                     state["cache"][key] = res
#
# /usr/local/lib/python3.10/site-packages/dask/local.py in reraise(exc, tb)
#     318     if exc.__traceback__ is not tb:
#     319         raise exc.with_traceback(tb)
# --> 320     raise exc
#     321
#     322
#
# /usr/local/lib/python3.10/site-packages/dask/local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     223     try:
#     224         task, data = loads(task_info)
# --> 225         result = _execute_task(task, data)
#     226         id = get_id()
#     227         result = dumps((result, id))
#
# /usr/local/lib/python3.10/site-packages/dask/core.py in _execute_task(arg, cache, dsk)
#     125         # temporaries by their reference count and can execute certain
#     126         # operations in-place.
# --> 127         return func(*(_execute_task(a, cache) for a in args))
#     128     elif not ishashable(arg):
#     129         return arg
#
# /usr/local/lib/python3.10/site-packages/dask_ml/model_selection/methods.py in fit_transform(est, X, y, error_score, fields, params, fit_params)
#     257             est = set_params(est, fields, params)
#     258             if hasattr(est, "fit_transform"):
# --> 259                 Xt = est.fit_transform(X, y, **fit_params)
#     260             else:
#     261                 est.fit(X, y, **fit_params)
#
# /usr/local/lib/python3.10/site-packages/cuml/internals/api_decorators.py in wrapper(*args, **kwargs)
#     186
#     187                     if process_return:
# --> 188                         ret = func(*args, **kwargs)
#     189                     else:
#     190                         return func(*args, **kwargs)
#
# /usr/local/lib/python3.10/site-packages/cuml/internals/api_decorators.py in dispatch(self, *args, **kwargs)
#     391         if hasattr(self, "dispatch_func"):
#     392             func_name = gpu_func.__name__
# --> 393             return self.dispatch_func(func_name, gpu_func, *args, **kwargs)
#     394         else:
#     395             return gpu_func(self, *args, **kwargs)
#
# /usr/local/lib/python3.10/site-packages/cuml/internals/api_decorators.py in wrapper(*args, **kwargs)
#     188                         ret = func(*args, **kwargs)
#     189                     else:
# --> 190                         return func(*args, **kwargs)
#     191
#     192                 return cm.process_return(ret)
#
# base.pyx in cuml.internals.base.UniversalBase.dispatch_func()
#
# pca.pyx in cuml.decomposition.pca.PCA.fit_transform()
#
# /usr/local/lib/python3.10/site-packages/cuml/internals/api_decorators.py in wrapper(*args, **kwargs)
#     186
#     187                     if process_return:
# --> 188                         ret = func(*args, **kwargs)
#     189                     else:
#     190                         return func(*args, **kwargs)
#
# /usr/local/lib/python3.10/site-packages/cuml/internals/api_decorators.py in dispatch(self, *args, **kwargs)
#     391         if hasattr(self, "dispatch_func"):
#     392             func_name = gpu_func.__name__
# --> 393             return self.dispatch_func(func_name, gpu_func, *args, **kwargs)
#     394         else:
#     395             return gpu_func(self, *args, **kwargs)
#
# /usr/local/lib/python3.10/site-packages/cuml/internals/api_decorators.py in wrapper(*args, **kwargs)
#     188                         ret = func(*args, **kwargs)
#     189                     else:
# --> 190                         return func(*args, **kwargs)
#     191
#     192                 return cm.process_return(ret)
#
# base.pyx in cuml.internals.base.UniversalBase.dispatch_func()
#
# pca.pyx in cuml.decomposition.pca.PCA.fit()
#
# /usr/local/lib/python3.10/site-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#     114         def inner(*args, **kwargs):
#     115             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116             result = func(*args, **kwargs)
#     117             libnvtx_pop_range(self.domain.handle)
#     118             return result
#
# /usr/local/lib/python3.10/site-packages/cuml/internals/input_utils.py in input_to_cuml_array(X, order, deepcopy, check_dtype, convert_to_dtype, check_mem_type, convert_to_mem_type, safe_dtype_conversion, check_cols, check_rows, fail_on_order, force_contiguous)
#     378
#     379     """
# --> 380     arr = CumlArray.from_input(
#     381         X,
#     382         order=order,
#
# /usr/local/lib/python3.10/site-packages/cuml/internals/memory_utils.py in cupy_rmm_wrapper(*args, **kwargs)
#      85         if GPU_ENABLED:
#      86             with cupy_using_allocator(rmm_cupy_allocator):
# ---> 87                 return func(*args, **kwargs)
#      88         return func(*args, **kwargs)
#      89
#
# /usr/local/lib/python3.10/site-packages/nvtx/nvtx.py in inner(*args, **kwargs)
#     114         def inner(*args, **kwargs):
#     115             libnvtx_push_range(self.attributes, self.domain.handle)
# --> 116             result = func(*args, **kwargs)
#     117             libnvtx_pop_range(self.domain.handle)
#     118             return result
#
# /usr/local/lib/python3.10/site-packages/cuml/internals/array.py in from_input(cls, X, order, deepcopy, check_dtype, convert_to_dtype, check_mem_type, convert_to_mem_type, safe_dtype_conversion, check_cols, check_rows, fail_on_order, force_contiguous)
#    1169         ) or make_copy:
#    1170             arr = cls(
# -> 1171                 arr.mem_type.xpy.array(
#    1172                     arr.to_output("array"), order=order, copy=make_copy
#    1173                 ),
#
# /usr/local/lib/python3.10/site-packages/cupy/_creation/from_data.py in array(obj, dtype, copy, order, subok, ndmin, blocking)
#      51
#      52     """
# ---> 53     return _core.array(obj, dtype, copy, order, subok, ndmin, blocking)
#      54
#      55
#
# cupy/_core/core.pyx in cupy._core.core.array()
#
# cupy/_core/core.pyx in cupy._core.core.array()
#
# cupy/_core/core.pyx in cupy._core.core._array_from_cupy_ndarray()
#
# cupy/_core/core.pyx in cupy._core.core._ndarray_base.astype()
#
# cupy/_core/core.pyx in cupy._core.core._ndarray_base.astype()
#
# cupy/_core/core.pyx in cupy._core.core.ndarray.__new__()
#
# cupy/_core/core.pyx in cupy._core.core._ndarray_base._init()
#
# cupy/cuda/memory.pyx in cupy.cuda.memory.alloc()
#
# /usr/local/lib/python3.10/site-packages/rmm/allocators/cupy.py in rmm_cupy_allocator(nbytes)
#      35
#      36     stream = Stream(obj=cupy.cuda.get_current_stream())
# ---> 37     buf = librmm.device_buffer.DeviceBuffer(size=nbytes, stream=stream)
#      38     dev_id = -1 if buf.ptr else cupy.cuda.device.get_device_id()
#      39     mem = cupy.cuda.UnownedMemory(
#
# device_buffer.pyx in rmm._lib.device_buffer.DeviceBuffer.__cinit__()
#
# MemoryError: std::bad_alloc: out_of_memory: CUDA error at: /usr/local/include/rmm/mr/device/cuda_memory_resource.hpp

# %% [markdown]
# ### Inner Loop: Hyperparameter Tuning

# %% [markdown]
# **Define Inner Cross-Validation Loop**
#
# - Using GroupKFold: For hyperparameter tuning within the outer training fold.

# %%
def start_inner_loop():

    # Defining inner cross-validation strategy
    inner_cv = GroupKFold(n_splits=3)

    # Creating pipelines and parameters grids for SVM and RF models
    pipeline_svm, pipeline_rf = create_pipelines()
    param_grid_svm, param_grid_rf = create_param_grids()

    # Performing RandomSearchCV for SVM and RF
    random_search_svm = randomized_search_svm(pipeline_svm,param_grid_svm,inner_cv)
    random_search_rf = randomized_search_rf(pipeline_rf,param_grid_rf,inner_cv)

    # Get the best models of SVM and RF
    best_model_svm = get_best_model_svm(random_search_svm)
    best_model_rf = get_best_model_rf(random_search_rf)

    evaluate_best_model_svm(best_model_svm)
    evaluate_best_model_rf(best_model_rf)

    return best_model_svm, best_model_rf

# %% [markdown]
# **Create Pipelines Including Preprocessing and Classifier**
# - For SVM and Random Forest separately
# - Include Preprocessing Steps:
#    - Scaling (StandardScaler)
#    - Principal Component Analysis (with number of components as hyperparameter)

# %%
# Pipeline for Support Vector Machine Classifier

def create_pipelines():
    pipeline_svm = Pipeline([
        ("scaler", StandardScaler()),
        ("pca",PCA()),
        ("classifier", SVC())
    ])

    # Pipeline for Random Forest Classifier
    pipeline_rf = Pipeline([
        ("scaler", StandardScaler()),
        ("pca",PCA()),
        ("classifier", RandomForestClassifier())
    ])

    return pipeline_svm, pipeline_rf

# %% [markdown]
# **Define Hyperparameter grids**

# %%
# Parameter grid for SVM
def create_param_grids():
    param_grid_svm = {
        'pca__n_components': [1000,2000,3000],
        'classifier__C': [0.01, 0.1, 1, 10, 100],
        'classifier__kernel': ['rbf'],
        'classifier__gamma': ['scale', 'auto']
    }


    # Parameter grid for Random Forest Classifier
    param_grid_rf = {
        'pca__n_components': [1000,2000,3000],
        'classifier__n_estimators': [100, 300],
        'classifier__max_depth': [10, 20]
    }

    return param_grid_svm, param_grid_rf

# %% [markdown]
# **Perform RandomizedSearch with Cross-validation for Hyperparameter Tuning**

# %%
# RandomziedSearchCV for SVM

def randomized_search_svm(pipeline_svm,param_grid_svm,inner_cv):
    random_search_svm = dcv.RandomizedSearchCV(
        estimator=pipeline_svm,
        param_distributions=param_grid_svm,
        cv = inner_cv.split(cp.asnumpy(X_outer_train),cp.asnumpy(y_outer_train), groups=cp.asnumpy(groups_outer_train)),
        scoring="f1_macro",
        n_iter=5,
        n_jobs=-1 # Uses all processors
    )

    random_search_svm.fit(X_outer_train, y_outer_train)

    return random_search_svm

# %%
def get_best_model_svm(random_search_svm):
    best_model_svm = random_search_svm.best_estimator_
    best_params_svm = random_search_svm.best_params_
    best_scores_svm = random_search_svm.best_score_

    print(f"Best params for SVM Model: {best_params_svm}")
    print(f"Best scoring(F1) for SVM Model: {best_scores_svm}")

    return best_model_svm

# %%
# RandomziedSearchCV for Random Forest Classifier
def randomized_search_rf(pipeline_rf, param_grid_rf, inner_cv):
    random_search_rf = dcv.RandomizedSearchCV(
        estimator=pipeline_rf,
        param_distributions=param_grid_rf,
        cv = inner_cv.split(cp.asnumpy(X_outer_train),cp.asnumpy(y_outer_train), groups=cp.asnumpy(groups_outer_train)),
        scoring="f1_macro",
        n_iter=5,
        n_jobs=-1 # Uses all processors
    )

    random_search_rf.fit(X_outer_train, y_outer_train)

    return random_search_rf

# %%
def get_best_model_rf(random_search_rf):
    best_model_rf = random_search_rf.best_estimator_
    best_params_rf = random_search_rf.best_params_
    best_scores_rf = random_search_rf.best_score_

    print(f"Best params for RF Model: {best_params_rf}")
    print(f"Best scoring(F1) for RF Model: {best_scores_rf}")

    return best_model_rf

# %% [markdown]
# **Evaluate Best Model from RandomizedSearch on Outer Validation Fold**

# %%
# For SVM Model
def evaluate_best_model_svm(best_model_svm):
    y_outer_val_pred_svm = best_model_svm.predict(X_outer_val)
    print(classification_report(y_outer_val,y_outer_val_pred_svm))

# %%
# For RF Model
def evaluate_best_model_rf(best_model_rf):
    y_outer_val_pred_rf = best_model_rf.predict(X_outer_val)
    print(classification_report(y_outer_val,y_outer_val_pred_rf))

# %% [markdown]
# **STEPS 9 ARE PENDING**
