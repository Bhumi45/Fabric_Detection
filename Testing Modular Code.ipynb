# %%
import os
os.chdir('Fabric_Detection')  # Replace with the name of your project folder

# %%
# !pip install pyngrok

# %%
# !ngrok config add-authtoken 2n4nycUkjsJii467VHnP30GZgy5_4MqAS8a435KLengXRZwW3
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
from pyngrok import ngrok

# Start ngrok to tunnel the Flask app
public_url = ngrok.connect(5000)
print(" * ngrok URL:", public_url)
# Out:
#  * ngrok URL: NgrokTunnel: "https://b534-35-221-197-163.ngrok-free.app" -> "http://localhost:5000"

# %%
import shutil
from google.colab import files

# Path to the folder you want to download
folder_path = '/content/Fabric_Detection/artifacts'  # Replace with your folder path

# Create a zip file from the folder
shutil.make_archive('/content/artifacts', 'zip', folder_path)

# Download the zip file
files.download('/content/artifacts.zip')

# %%
files.download('/content/artifacts.zip')

# %%
# !npm install -g localtunnel
# Out:
# added 22 packages, and audited 23 packages in 2s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# 1 moderate severity vulnerability
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.

# %%
# !lt --port 5000 --subdomain yoursubdomain
# Out:
# your url is: https://yoursubdomain.loca.lt

# %%
ssh -R 80:localhost:5000 serveo.net
# Out:
#   File "<ipython-input-1-ba8cecbaa95f>", line 1
#     ssh -R 80:localhost:5000 serveo.net
#            ^
# SyntaxError: invalid syntax

# %%
import gc
gc.collect()
# Out:
# 0

# %%
# !npm install -g localtunnel
# Out:
# added 22 packages, and audited 23 packages in 2s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# 1 moderate severity vulnerability
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.

# %%
# !lt --port 5000
# Out:
# your url is: https://puny-cities-switch.loca.lt
# ^C

# %%
# !curl https://loca.lt/mytunnelpassword
# Out:
# 34.150.131.199

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Replace 'my_folder_backup.zip' with the name of your zip file
# !cp /content/artifacts.zip /content/drive/MyDrive/

# %%
# Copy the zip file to Google Drive
# !cp /content/artifacts.zip /content/drive/MyDrive/

# List the contents of Google Drive to verify the file has been copied
# !ls /content/drive/MyDrive/
# Out:
#  1534915025-178527051.pdf
# 'AI Engineer Master’s Program.gdoc'
# 'AI PROJECTS'
# 'Alchemy Parth.mp4'
#  artifacts.zip
# 'Blank Quiz.gform'
#  cbseresults.nic.txt
#  chords_part.mp4
#  Civics.gdoc
#  Classroom
# 'Colab Notebooks'
# 'Copy of 100 Days English Speaking Tracker.gsheet'
# 'Copy of 8_3.pptx'
# 'Copy of Doodle World Wildlife Day by Slidesgo.gslides'
# 'Copy of Lesson plan.gdoc'
# 'Copy of zixe3-xd8hf.azw3'
# 'Data Analytics and Python.gdoc'
#  DATA_HUB
# 'Data Science'
# 'Data Science with Python'
#  Datasets
#  EBSCO
#  English_Summer_Project.wmv
#  e.PNG
# 'Epson iPrint'
#  Essay.gdoc
# 'Fabric Detection Project'
#  GAME_OF_
# 'Google AI Studio'
# 'Lesson plan (1).gdoc'
# 'Lesson plan (1).gslides'
# 'Lesson plan (2).gdoc'
# 'Lesson plan.gdoc'
# 'Lesson plan.gslides'
#  machine_learning.pdf
# 'Make an excel sheet:'$'\n''Variable'$'\t''    Definition....gsheet'
# 'MLS Slides.zip'
# 'MUTABLE VS IMMUTABLE.ipynb'
#  Plan.gdoc
#  Printed_1.gdoc
# 'Project Sign-up.gform'
# ...
