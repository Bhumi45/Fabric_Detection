# %%
# Import Libararies
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
import os

# %% [markdown]
# Printing denim images from 1 to 100

# %%
folder_path = "E:\\Projects vijAI\\Fabric Detection\\Provided Content\\textures 3\\denim"
image_files = glob.glob(os.path.join(folder_path, "*.png"))


def build_gabor_filters():
    filters = []
    ksize = 31  # Size of the filter
    sigma = 4.0  # Standard deviation of the Gaussian envelope
    lambd = 10.0  # Wavelength of the sinusoidal factor
    gamma = 0.5  # Spatial aspect ratio
    psi = 0  # Phase offset

    # Define filters at 45 and 135 degrees
    for theta in np.deg2rad([45, 135]):  # Convert degrees to radians
        kern = cv2.getGaborKernel((ksize, ksize), sigma, theta, lambd, gamma, psi, ktype=cv2.CV_32F)
        filters.append(kern)
    return filters

def process_image_with_gabor(image, filters):
    responses = []
    for kern in filters:
        fimg = cv2.filter2D(image, cv2.CV_8UC3, kern)
        responses.append(fimg)
    return responses


for count,image_name in enumerate(image_files,start=1):
    if count==100:
        break

    # Load the image
    image = cv2.imread(image_name, cv2.IMREAD_GRAYSCALE)
    
    # Build Gabor filters
    gabor_filters = build_gabor_filters()
    
    # Process the image with Gabor filters
    responses = process_image_with_gabor(image, gabor_filters)
    
    # Display the results
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 3, 1)
    plt.imshow(image, cmap='gray')
    plt.title('Original Image')
    
    plt.subplot(1, 3, 2)
    plt.imshow(responses[0], cmap='gray')
    plt.title('45 Degree Filter')
    
    plt.subplot(1, 3, 3)
    plt.imshow(responses[1], cmap='gray')
    plt.title('135 Degree Filter')
    
    plt.show()

# %% [markdown]
# Priting denim images from 101 to 200

# %%
folder_path = "E:\\Projects vijAI\\Fabric Detection\\Provided Content\\textures 3\\denim"
image_files = glob.glob(os.path.join(folder_path, "*.png"))

for count,image_name in enumerate(image_files,start=1):
    if count==200:
        break
    
    if count>100:
        # Load the image
        image = cv2.imread(image_name, cv2.IMREAD_GRAYSCALE)
        
        # Build Gabor filters
        gabor_filters = build_gabor_filters()
        
        # Process the image with Gabor filters
        responses = process_image_with_gabor(image, gabor_filters)
        
        # Display the results
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 3, 1)
        plt.imshow(image, cmap='gray')
        plt.title('Original Image')
        
        plt.subplot(1, 3, 2)
        plt.imshow(responses[0], cmap='gray')
        plt.title('45 Degree Filter')
        
        plt.subplot(1, 3, 3)
        plt.imshow(responses[1], cmap='gray')
        plt.title('135 Degree Filter')
        
        plt.show()

    def build_gabor_filters():
        filters = []
        ksize = 31  # Size of the filter
        sigma = 4.0  # Standard deviation of the Gaussian envelope
        lambd = 10.0  # Wavelength of the sinusoidal factor
        gamma = 0.5  # Spatial aspect ratio
        psi = 0  # Phase offset

        # Define filters at 45 and 135 degrees
        for theta in np.deg2rad([45, 135]):  # Convert degrees to radians
            kern = cv2.getGaborKernel((ksize, ksize), sigma, theta, lambd, gamma, psi, ktype=cv2.CV_32F)
            filters.append(kern)
        return filters

    def process_image_with_gabor(image, filters):
        responses = []
        for kern in filters:
            fimg = cv2.filter2D(image, cv2.CV_8UC3, kern)
            responses.append(fimg)
        return responses

# %% [markdown]
# Priting denim images from 201 to 300

# %%
folder_path = "E:\\Projects vijAI\\Fabric Detection\\Provided Content\\textures 3\\denim"
image_files = glob.glob(os.path.join(folder_path, "*.jpg"))

for count,image_name in enumerate(image_files,start=1):
    if count==300:
        break
    
    if count>200:
        # Load the image
        image = cv2.imread(image_name, cv2.IMREAD_GRAYSCALE)
        
        # Build Gabor filters
        gabor_filters = build_gabor_filters()
        
        # Process the image with Gabor filters
        responses = process_image_with_gabor(image, gabor_filters)
        
        # Display the results
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 3, 1)
        plt.imshow(image, cmap='gray')
        plt.title('Original Image')
        
        plt.subplot(1, 3, 2)
        plt.imshow(responses[0], cmap='gray')
        plt.title('45 Degree Filter')
        
        plt.subplot(1, 3, 3)
        plt.imshow(responses[1], cmap='gray')
        plt.title('135 Degree Filter')
        
        plt.show()

    def build_gabor_filters():
        filters = []
        ksize = 31  # Size of the filter
        sigma = 4.0  # Standard deviation of the Gaussian envelope
        lambd = 10.0  # Wavelength of the sinusoidal factor
        gamma = 0.5  # Spatial aspect ratio
        psi = 0  # Phase offset

        # Define filters at 45 and 135 degrees
        for theta in np.deg2rad([45, 135]):  # Convert degrees to radians
            kern = cv2.getGaborKernel((ksize, ksize), sigma, theta, lambd, gamma, psi, ktype=cv2.CV_32F)
            filters.append(kern)
        return filters

    def process_image_with_gabor(image, filters):
        responses = []
        for kern in filters:
            fimg = cv2.filter2D(image, cv2.CV_8UC3, kern)
            responses.append(fimg)
        return responses

# %% [markdown]
# Priting denim images from 301 to 400

# %%
folder_path = "E:\\Projects vijAI\\Fabric Detection\\Provided Content\\textures 3\\denim"
image_files = glob.glob(os.path.join(folder_path, "*.jpg"))

for count,image_name in enumerate(image_files,start=1):
    if count==400:
        break
    
    if count>300:
        # Load the image
        image = cv2.imread(image_name, cv2.IMREAD_GRAYSCALE)
        
        # Build Gabor filters
        gabor_filters = build_gabor_filters()
        
        # Process the image with Gabor filters
        responses = process_image_with_gabor(image, gabor_filters)
        
        # Display the results
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 3, 1)
        plt.imshow(image, cmap='gray')
        plt.title('Original Image')
        
        plt.subplot(1, 3, 2)
        plt.imshow(responses[0], cmap='gray')
        plt.title('45 Degree Filter')
        
        plt.subplot(1, 3, 3)
        plt.imshow(responses[1], cmap='gray')
        plt.title('135 Degree Filter')
        
        plt.show()

    def build_gabor_filters():
        filters = []
        ksize = 31  # Size of the filter
        sigma = 4.0  # Standard deviation of the Gaussian envelope
        lambd = 10.0  # Wavelength of the sinusoidal factor
        gamma = 0.5  # Spatial aspect ratio
        psi = 0  # Phase offset

        # Define filters at 45 and 135 degrees
        for theta in np.deg2rad([45, 135]):  # Convert degrees to radians
            kern = cv2.getGaborKernel((ksize, ksize), sigma, theta, lambd, gamma, psi, ktype=cv2.CV_32F)
            filters.append(kern)
        return filters

    def process_image_with_gabor(image, filters):
        responses = []
        for kern in filters:
            fimg = cv2.filter2D(image, cv2.CV_8UC3, kern)
            responses.append(fimg)
        return responses

# %% [markdown]
# Priting denim images from 401 to 500

# %%
folder_path = "E:\\Projects vijAI\\Fabric Detection\\Provided Content\\textures 3\\denim"
image_files = glob.glob(os.path.join(folder_path, "*.jpg"))

for count,image_name in enumerate(image_files,start=1):
    if count==500:
        break
    
    if count>400:
        # Load the image
        image = cv2.imread(image_name, cv2.IMREAD_GRAYSCALE)
        
        # Build Gabor filters
        gabor_filters = build_gabor_filters()
        
        # Process the image with Gabor filters
        responses = process_image_with_gabor(image, gabor_filters)
        
        # Display the results
        plt.figure(figsize=(10, 5))
        plt.subplot(1, 3, 1)
        plt.imshow(image, cmap='gray')
        plt.title('Original Image')
        
        plt.subplot(1, 3, 2)
        plt.imshow(responses[0], cmap='gray')
        plt.title('45 Degree Filter')
        
        plt.subplot(1, 3, 3)
        plt.imshow(responses[1], cmap='gray')
        plt.title('135 Degree Filter')
        
        plt.show()

    def build_gabor_filters():
        filters = []
        ksize = 31  # Size of the filter
        sigma = 4.0  # Standard deviation of the Gaussian envelope
        lambd = 10.0  # Wavelength of the sinusoidal factor
        gamma = 0.5  # Spatial aspect ratio
        psi = 0  # Phase offset

        # Define filters at 45 and 135 degrees
        for theta in np.deg2rad([45, 135]):  # Convert degrees to radians
            kern = cv2.getGaborKernel((ksize, ksize), sigma, theta, lambd, gamma, psi, ktype=cv2.CV_32F)
            filters.append(kern)
        return filters

    def process_image_with_gabor(image, filters):
        responses = []
        for kern in filters:
            fimg = cv2.filter2D(image, cv2.CV_8UC3, kern)
            responses.append(fimg)
        return responses

# %%
import os

# Define the folder path
folder_path = "E:\\Projects vijAI\\Fabric Detection\\Provided Content\\textures 3\\denim"

# Initialize counters
jpg_count = 0
png_count = 0

# Iterate through the files in the folder
for file_name in os.listdir(folder_path):
    if file_name.endswith(".jpg"):
        jpg_count += 1
    elif file_name.endswith(".png"):
        png_count += 1

# Print the results
print(f"Number of .jpg images: {jpg_count}")
print(f"Number of .png images: {png_count}")
